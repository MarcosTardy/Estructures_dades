# %% [markdown]
# ## Exercici 1

# %%
#Crea una llista que agrupi els mesos de l’any en trimestres (1T: gener, febrer i març; 2T: abril, maig, juny...), és a dir, una llista amb 4 llistes dins.
mesos=[["gener","febrer","març"],["abril","maig","juny"],["juliol","agost","setembre"],["octubre","novembre","decembre"]]

# %% [markdown]
# ## Exercici 2

# %%
#Crea un codi que et permeti accedir a:
#El segon mes del primer trimestre.
#Els mesos del primer trimestre.
#Setembre i octubre.
mesos=[["gener","febrer","març"],["abril","maig","juny"],["juliol","agost","setembre"],["octubre","novembre","decembre"]]
segon_primer=print("El segon mes del primer trimestre és: ", mesos[0][1])
mesos_primer=print("Els mesos del primer trimestre son: ", mesos[0])
setembre_octubre=print("Setembre: ", mesos[2][2], "y octubre: ", mesos[3][0])
# Out:
# El segon mes del primer trimestre és:  febrer
# Els mesos del primer trimestre son:  ['gener', 'febrer', 'març']
# Setembre:  setembre y octubre:  octubre

# %% [markdown]
# ## Exercici 3

# %%
#Crea una llista amb nombres desordenats i respon a les següents preguntes:
llista=[1,8,9,5,6,7,5,8,4,3,3,5,6,7,3,1,2,3,5,7,8,5,3,5,6,4,2,4,5,7,5,7,9,3,2,5,6,7]
quants_n=len(llista) #Compta quants números o elements hi ha a la llista.
print("Hi han ", quants_n, "elements en la llista.")
q_tres=llista.count(3) #Compta la quantitat de números tres que hi ha en la llista
print("Hi han ", q_tres, "números tres en la llista.")
#Compta la quantitat de números tres y quatre.
c=0
n_tres=0
n_quatre=0
while len(llista)>c:
    if llista[c]==3:
        c=c+1
        n_tres=n_tres+1
    elif llista[c]==4:
        c=c+1
        n_quatre=n_quatre+1
    else:
        c=c+1
print("Hi han ", n_tres+n_quatre, "números tres i quatre en total en la llista.")

#Quin es el número més gran.
n_mes_gran=max(llista)
print("El número més gran és: ", n_mes_gran)

#Els tres números més petits
num1=max(llista)
num2=max(llista)
num3=max(llista)
for numero in llista:
    if numero<num1:
        num1=num2
        num2=num3
        num3=numero
    elif numero<num2:
        numero3=num2
        num2=numero
    elif numero<num3:
        num3=numero
        
print("Els tres números més petits de la llista son: ",num1,", ",num2,", ",num3)

#Rang de la llista:
valor_min=min(llista)
valor_max=max(llista)
rang=valor_max-valor_min
print("El rang de la llista és: ", rang)
# Out:
# Hi han  38 elements en la llista.
# Hi han  6 números tres en la llista.
# Hi han  9 números tres i quatre en total en la llista.
# El número més gran és:  9
# Els tres números més petits de la llista son:  1 ,  1 ,  2
# El rang de la llista és:  8

# %% [markdown]
# ## Exercici 4

# %%
#Afegeix fresa
compra = { "Pomes" : {"Qty": 5, "€": 0.42}, "Peres" : {"Qty": 3, "€": 0.66} }
compra["Fresa"]={'Qty': 10, '€': 0.1}
print("La llista de la compra és: ", compra)
# Out:
# La llista de la compra és:  {'Pomes': {'Qty': 5, '€': 0.42}, 'Peres': {'Qty': 3, '€': 0.66}, 'Fresa': {'Qty': 10, '€': 0.1}}

# %%
#Calcula preu de les peres
x=compra["Peres"]["Qty"]
y=compra["Peres"]['€']
print("El preu de les peres és: ", x*y)
# Out:
# El preu de les peres és:  1.98

# %%
#Compta fruites comprades
cont=len(compra.keys())
print("S'han comprat ", cont, "fruites.")
# Out:
# S'han comprat  3 fruites.

# %%
#Fruita més cara
max_name=""
max_value=0
for i,subdic in compra.items():
    if subdic['€']>max_value:
        max_value=subdic['€']
        max_name=i
print("La fruita més cara és: ", max_name)
# Out:
# La fruita més cara és:  Peres
